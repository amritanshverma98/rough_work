# %%
non_frauds = [
    {
        'call_transcript': '''Billing & statements — clarify charges, fees, interest

Speaker 1 : Thank you for calling American Express. You’re speaking with Maya. How can I help today?
Speaker 2 : Hi Maya, this is Alex Bennett. I’m calling about my September statement. The interest looks a lot higher than usual and I’d like to understand why.
Speaker 1 : I’m happy to explain, Alex. I’ll just verify your account. Could you confirm your full name, last four digits on the card, billing ZIP, and email on file?
Speaker 2 : Sure—Alex Bennett, 4421, ZIP 94110, and the email is alex.bennett@baymail.com
.
Speaker 1 : Thank you—verified. Looking at August, I see you carried a balance of $1,920. Your payment posted on September 18, two days after the due date, which triggered a $29 late fee and interest on the average daily balance. That’s why September’s finance charge is higher.
Speaker 2 : Okay, that tracks. I usually pay on the due date, so I must have missed the reminder. Could that late fee be reconsidered? I’ve been on time for years.
Speaker 1 : You do have a strong history. I can submit a one-time courtesy waiver right now. It’ll post within 24–48 hours and reflect on your next statement.
Speaker 2 : I’d appreciate that. Also, the due date is the 16th—can I move it closer to my paycheck on the 25th?
Speaker 1 : Absolutely. We can shift your statement cycle so the payment due date lands around the 25th. It will take one cycle to settle in. Shall I proceed?
Speaker 2 : Yes, please.
Speaker 1 : Done. To help avoid this again, I recommend AutoPay for statement balance and push reminders. Would you like me to enroll you now?
Speaker 2 : Yes—use my Chase checking ending 3187.
Speaker 1 : AutoPay set. You’ll receive confirmation at alex.bennett@baymail.com
. Anything else on the statement?
Speaker 2 : There’s a $3.50 from CloudStore—I forgot that’s my storage subscription. All good.
Speaker 1 : Perfect. Anything more I can clarify?
Speaker 2 : No, you’ve answered everything. Thanks for your help.
Speaker 1 : My pleasure, Alex. Have a great day.''',
        'signal': '''Genuine signals: Smooth multi-factor verification; consistent personal details; reasonable questions; accepts policy and timelines; proactively enrolls in AutoPay and date change—no pressure to bypass controls.'''
    },
    {
        'call_transcript': '''Payments — set up AutoPay, confirm posting

Speaker 1 : American Express Payments, this is Jordan. How may I assist?
Speaker 2 : Hi Jordan, Priya Mehta here. I made a payment from my Wells Fargo account this morning and it hasn’t shown up yet. Just checking if that’s normal.
Speaker 1 : I’ll take a look. May I verify your full name, last four digits, billing ZIP, and email?
Speaker 2 : Priya Mehta, 7732, ZIP 95014, email priya.mehta@gmail.com
.
Speaker 1 : Thank you—verified. I see an electronic payment initiated at 8:42 a.m. today, reference 7C1-1042, for $600. External bank transfers can take 24–48 hours to fully post.
Speaker 2 : Great. And once it posts, my available credit increases right away?
Speaker 1 : Yes, your available credit and fraud thresholds will adjust as soon as it posts. You’ll also get a push and email confirmation.
Speaker 2 : Perfect. Can we set AutoPay to minimum due for now? I travel a lot.
Speaker 1 : Certainly. Which funding account would you like to use?
Speaker 2 : Wells Fargo checking ending 6751.
Speaker 1 : AutoPay to minimum due is set. Do you want due-date reminders by SMS and email?
Speaker 2 : Yes—my mobile is 415-555-0187.
Speaker 1 : Added. I also recommend enabling “payment posted” notifications so you get a ping when today’s payment clears.
Speaker 2 : Please turn that on. Also, I noticed a pending duplicate payment from last month that eventually dropped. Is that normal?
Speaker 1 : It can happen if a bank re-attempts a connection; duplicates usually fall off before posting. If two do post, we’ll help reverse one.
Speaker 2 : Good to know. Thanks for the reassurance.
Speaker 1 : Happy to help. Anything else today?
Speaker 2 : That’s it—thanks, Jordan.
Speaker 1 : You’re welcome, Priya. Watch for those confirmations shortly.''',
        'signal': '''Genuine signals: Eager to verify; provides full, consistent contact info; asks practical posting and notification questions; requests conservative AutoPay; accepts standard timelines.'''
    },
    {
        'call_transcript': '''Card activation & onboarding

Speaker 1 : You’ve reached American Express, this is Elena.
Speaker 2 : Hi Elena, Daniel Ortiz here. I just received my new card and want to activate it, set a PIN, and add it to my phone.
Speaker 1 : I’ll help with that. Please verify full name, last four digits, billing ZIP, and email on file.
Speaker 2 : Daniel Ortiz, 1098, ZIP 60657, email daniel.ortiz@northmail.net
.
Speaker 1 : Thank you—verified. I’m activating the card… done. Would you like to set a 4-digit PIN now?
Speaker 2 : Yes—PIN set, please.
Speaker 1 : Great, PIN is established. I’m sending a secure push to your iPhone ending in device ID 32EF. Approve the prompt—don’t read any codes aloud.
Speaker 2 : Approved.
Speaker 1 : Perfect—Apple Wallet is provisioned. Quick orientation: 4x points at restaurants, 3x on transit, 1x elsewhere. You’ve got trip delay insurance and extended warranty on eligible purchases.
Speaker 2 : Very nice. Any tips for first-time use?
Speaker 1 : Try a small contactless purchase at a grocery or pharmacy to warm up the fraud models. I’ll also enable transaction alerts and Amex Offers so you can add discounts before checkout.
Speaker 2 : Great. Can I request a backup physical card to my home address, 2110 N. Racine Ave, Apt 3A, Chicago, IL 60614?
Speaker 1 : Yes—shipping to your on-file address is confirmed. Delivery 3–5 business days.
Speaker 2 : Awesome. If a purchase gets declined at a new merchant, what should I do?
Speaker 1 : You’ll get a real-time alert—tap “Confirm It’s Me” in the app and retry. If needed, call us from the number on the back of the card.
Speaker 2 : Got it. Thanks for the smooth setup.
Speaker 1 : Welcome aboard, Daniel—enjoy your card.''',
        'signal': '''Genuine signals: Full verification; accepts on-file shipping; follows in-app security steps; asks standard onboarding questions; leans into alerts/offers rather than pressure.'''
    },
    {
        'call_transcript': '''Rewards & benefits — redemption/partner transfer

Speaker 1 : American Express Membership Rewards, this is Sam.
Speaker 2 : Hi Sam, Rochelle Kim here. I’m planning a Boston trip and want to transfer points to an airline.
Speaker 1 : Happy to help, Rochelle. Let me verify last four digits, billing ZIP, and email.
Speaker 2 : 3511, ZIP 10003, email rochelle.kim@eastmail.com
.
Speaker 1 : Thanks—verified. You have 78,400 points. For Boston, Delta and JetBlue are good options; Delta currently has a 15% transfer bonus.
Speaker 2 : Nice. If I transfer, how long until I can book?
Speaker 1 : Delta transfers are typically instant; JetBlue can take up to 24 hours. I recommend searching award space first to make sure flights are available.
Speaker 2 : I saw seats on Delta next Friday. Let’s transfer 70,000 to Delta.
Speaker 1 : I’ll send a secure approval to your Amex app—please confirm.
Speaker 2 : Approved.
Speaker 1 : Transfer completed. With the 15% bonus, you’ll receive 80,500 Delta miles. I’ve emailed confirmation and posted it to Secure Messages.
Speaker 2 : Great. Do award tickets earn miles?
Speaker 1 : Typically no, but you’ll earn card points on taxes/fees you pay with the card. Also, remember award tickets may have change restrictions.
Speaker 2 : Understood. Could you remind me of my lounge access?
Speaker 1 : With your card, you have access to partner lounges when flying the same day—details are in the Benefits tab.
Speaker 2 : Perfect. Thanks for the guidance.
Speaker 1 : Anytime—enjoy Boston!''',
        'signal': '''Genuine signals: Cooperative verification; uses in-app approval; realistic timing and availability questions; acknowledges rules; no attempts to rush or game the system.'''
    },
    {
        'call_transcript': '''Disputes — goods not received

Speaker 1 : Amex Disputes, this is Karen.
Speaker 2 : Hi, Mohit Verma calling. I ordered a coffee machine from “BeanWorks” on October 2 for $249.99 and it still hasn’t arrived.
Speaker 1 : I’m sorry about that, Mohit. Let me verify last four digits, ZIP, and email.
Speaker 2 : 6680, ZIP 10001, email mohit.verma@hudsonmail.com
.
Speaker 1 : Thank you—verified. I see the transaction posted October 3. Do you have any tracking or merchant communication?
Speaker 2 : Tracking shows “label created” but no movement for two weeks. I emailed the merchant three times and got no reply.
Speaker 1 : Understood. I’ll open a “goods not received” case and issue a temporary credit while we request proof of shipment and delivery from the merchant. If they can’t provide it, the credit becomes permanent.
Speaker 2 : Sounds fair. If it turns up later, I’ll let you know.
Speaker 1 : Thank you. I’ve created Case #D-10477. You’ll receive an email shortly with what we filed and any documents you can add—screenshots, order confirmation, and the tracking page.
Speaker 2 : I’ll upload those today.
Speaker 1 : I’m also enabling purchase alerts and card-on-file notifications so future orders are easier to track.
Speaker 2 : Please do.
Speaker 1 : Expect an update within 10–14 days, and you can check progress in the app under “Disputes.”
Speaker 2 : Great—appreciate the help.
Speaker 1 : You’re welcome, Mohit.''',
        'signal': '''Genuine signals: Provides exact amounts/dates; tried merchant first; agrees to provide documentation; accepts dispute cadence; passes verification with ease.'''
    },
    {
        'call_transcript': '''Account maintenance — update address/email

Speaker 1 : American Express, Alicia speaking.
Speaker 2 : Hi Alicia, Peter Wu here. I moved and need to update my mailing address but keep paperless statements.
Speaker 1 : Absolutely. For security, please confirm last four digits, current email, and date of birth.
Speaker 2 : 5407, peter.wu@outlookmail.com
, and DOB 05/18/1989.
Speaker 1 : Verified—thank you. What’s your new address?
Speaker 2 : 1825 Lakeview Ave, Apt 5B, Seattle, WA 98109.
Speaker 1 : Address updated. Would you like a replacement card shipped there, or keep your current one?
Speaker 2 : Keep the current one. Just make sure alerts go to my mobile 206-555-0142.
Speaker 1 : I’ve added SMS alerts and confirmed your email stays the same. You’ll receive a confirmation for the address change within a few minutes.
Speaker 2 : Great. While we’re here, could you confirm my paperless enrollment?
Speaker 1 : Yes—paperless is active for statements and tax forms.
Speaker 2 : Perfect. I’m all set.
Speaker 1 : Anything else I can help with?
Speaker 2 : That’s everything—thanks for the quick update.
Speaker 1 : My pleasure, Peter. Enjoy your day.''',
        'signal': '''Genuine signals: Offers multiple identifiers; standard maintenance request; accepts confirmation notifications; no push for alternate shipping or unusual changes.'''
    },
    {
        'call_transcript': '''Credit management — limit increase

Speaker 1 : You’re speaking with Omar at American Express.
Speaker 2 : Hi Omar, Sarah Lopez here. I’m renovating my kitchen and wondering if I can increase my credit limit to help with materials.
Speaker 1 : I can review options. May I verify last four digits, ZIP, email, and your current annual income?
Speaker 2 : 2843, ZIP 60614, email sarah.lopez@midwestmail.com
, income $132,000.
Speaker 1 : Thank you—verified. Based on your repayment history, I can submit a request to raise your limit from $12,000 to $18,000. This typically uses a soft inquiry; if a hard pull is needed, we’ll notify you first.
Speaker 2 : That’s fine. Please proceed.
Speaker 1 : Submitting now… approved at $18,000. You’ll see it immediately.
Speaker 2 : Wonderful. Any tips to keep utilization healthy while I’m buying appliances?
Speaker 1 : Consider mid-cycle payments, and I can set a spend alert when you reach 30% of the new limit—$5,400.
Speaker 2 : Let’s do that. Also, is there any promotional APR I should know about?
Speaker 1 : Not currently on this account, but I’ve added a note to review for targeted offers next cycle.
Speaker 2 : Great. Thanks for the guidance.
Speaker 1 : Happy to help, Sarah.''',
        'signal': '''Genuine signals: Transparent income and consent; comfortable with soft/hard inquiry disclosure; focuses on budgeting and alerts; cooperative tone throughout.'''
    },
    {
        'call_transcript': '''Travel & international use — travel prep, FX tips

Speaker 1 : American Express Travel, this is Neha.
Speaker 2 : Hi Neha, David Park here. I’m traveling to Singapore next week and want to be sure my card works there.
Speaker 1 : I’ll check your profile. Please verify last four digits, billing ZIP, and email.
Speaker 2 : 9176, ZIP 30309, email david.park@peachmail.com
.
Speaker 1 : Thank you—verified. Your card has no foreign transaction fees. Contactless and chip are widely accepted in Singapore. We don’t require travel notices, but it helps to keep your contact info current.
Speaker 2 : It’s current. Any tips on dynamic currency conversion?
Speaker 1 : Great question—always choose to be charged in the local currency (SGD). Merchants offering to convert to USD often add a markup.
Speaker 2 : Noted. How about ATMs?
Speaker 1 : You can use ATMs for cash, but local operators may charge fees; paying by card is usually better. I’ll enable international purchase alerts so you see transactions in real time.
Speaker 2 : Please do. My hotel is Marina View Residences, 6 Marina Blvd, Singapore 018985, in case that helps with your risk checks.
Speaker 1 : Thanks—I’ve added a travel note. If we ever need to confirm a charge, we’ll send an in-app prompt and SMS.
Speaker 2 : Perfect. Appreciate the advice.
Speaker 1 : Safe travels, David. Enjoy Singapore.''',
        'signal': '''Genuine signals: Clear itinerary; seeks best-practice guidance; embraces alerts; provides consistent identifiers; no push to weaken controls.'''
    },
    {
        'call_transcript': '''Digital access — login help, new device

Speaker 1 : American Express Digital Support, this is Lila.
Speaker 2 : Hi Lila, Tom Bradley here. I changed phones and can’t log in to the app.
Speaker 1 : I’ll help get you back in. Please verify last four digits, billing ZIP, email, and your previous device model.
Speaker 2 : 3900, ZIP 75202, email tom.bradley@oakmail.com
, and my old phone was an iPhone 12.
Speaker 1 : Verified—thank you. I’ll send a secure approval to your email and a push to the new device ending in ID 9A21. Please approve both—don’t read any codes aloud.
Speaker 2 : Done—both approved.
Speaker 1 : Great. I’ve reset your login, re-enabled Face ID, and turned on sign-in alerts. I also recommend setting a longer passphrase—would you like me to prompt you to update it now?
Speaker 2 : Yes, let’s do it.
Speaker 1 : Passphrase updated successfully. I’m clearing any old sessions to prevent confusion.
Speaker 2 : Appreciate that. I had one odd SMS last night asking for a code—glad I didn’t share it.
Speaker 1 : Good call—we’ll never ask you to read a passcode to us. If you see anything suspicious, report it in the app under Security.
Speaker 2 : Will do. Thanks for the quick rescue.
Speaker 1 : Anytime, Tom—have a great day.''',
        'signal': '''Genuine signals: Completes multi-channel authentication; follows security instructions; asks for safer settings; reports suspicious SMS proactively.'''
    },
    {
        'call_transcript': '''Card replacement — lost/damaged

Speaker 1 : American Express Card Services, Priyanka speaking.
Speaker 2 : Hi, Emily Carter here. I misplaced my card this morning and want to freeze it and request a replacement.
Speaker 1 : I’m sorry that happened, Emily. Let’s secure your account. Please confirm last four digits, billing ZIP, email, and mobile number.
Speaker 2 : 2259, ZIP 75201, email emily.carter@elmmail.com
, mobile 214-555-0173.
Speaker 1 : Thank you—verified. I’ve locked your card to block new purchases while keeping your recurring payments active. Would you like overnight delivery to 4102 Maple St, Dallas, TX 75201?
Speaker 2 : Yes, that’s my address.
Speaker 1 : Replacement is ordered with tracking sent to your email. If you’ve added the card to Apple Pay or Google Pay, those tokens will update automatically once you activate the new card.
Speaker 2 : Great. I do have it on Apple Pay—so I can still use the wallet?
Speaker 1 : Yes, once the new card is active, your wallet will reflect the updated number. Meanwhile, the freeze prevents new physical card transactions.
Speaker 2 : Perfect. If the old card turns up, should I destroy it?
Speaker 1 : Yes—cut through the chip and magnetic stripe. Then activate your new card by phone or in the app.
Speaker 2 : Thanks for the clear steps.
Speaker 1 : You’re welcome, Emily. Anything else I can help with?
Speaker 2 : That’s all—really appreciate your help.
Speaker 1 : Glad to assist. Have a good day.''',
        'signal': '''Genuine signals: Immediate freeze and address confirmation; accepts standard shipping; embraces wallet token update; completes verification without resistance.'''
    }
]

frauds = [
    {
        'call_transcript': """1) Account-takeover setup — change email/phone

Speaker 1 : American Express, this is Noah. How may I help today?
Speaker 2 : Hi, I need you to update my contact details right away. Change my phone to 415-555-0134 and email to quickfix@workmail.net
. I’m boarding in ten minutes.
Speaker 1 : I can help with contact updates after verification. May I have your full name, the last four digits on the card, your billing ZIP, and the current email on file?
Speaker 2 : It’s Michael Thompson, last four 9921. I don’t remember the email you have—just switch it to the new one so I stop missing alerts.
Speaker 1 : Understood. For your protection, I’ll send an approval to the existing phone and email. Please approve on your device; don’t read any codes aloud.
Speaker 2 : I can’t access the old phone; it was stolen yesterday. Just override and put in 415-555-0134.
Speaker 1 : I’m sorry about the phone. We can still verify by in-app approval, a one-time call-back to the number on file, or secure ID review. Which would you like?
Speaker 2 : None. I told you I’m boarding. Move the number now and I’ll confirm later.
Speaker 1 : I can’t change contact points without authentication on a registered channel. If you’d like, I can start our recovery process and text a secure link to the number on file.
Speaker 2 : Don’t text that number. I don’t want the current owner seeing anything.
Speaker 1 : I understand the concern. The account holder can also verify via the Amex app or by returning our call from the number on the back of the card.
Speaker 2 : Look, the security phrase is “green apple.” That should be enough.
Speaker 1 : We don’t rely on legacy phrases. We need a successful step-up on a registered channel.
Speaker 2 : You’re wasting my time. Forget it.
Speaker 1 : If the cardholder becomes available to verify, we’ll complete the update right away. Is there anything else I can assist with today?
Speaker 2 : No.
Speaker 1 : Thank you for calling American Express.""",
        'signal': 'Refuses/avoids verification; urgent demand to replace phone/email; claims total loss of all registered channels; pushes override; offers dubious “security phrase”; blocks contact to on-file details.'
    },
    {
        'call_transcript': """2) “Card not received” reship — new address request

Speaker 1 : You’ve reached American Express, Chloe speaking.
Speaker 2 : My new card never arrived. Reship it today to 44 Harbor Industrial Rd, Unit C, Albany, NY 12202. Use overnight.
Speaker 1 : I’m sorry to hear that. I’ll help after verification. May I have your full name, last four digits, billing ZIP, and the email we have on file?
Speaker 2 : Jonathan Reed, 4610. I don’t have time for the rest; I’m moving warehouses and need the card at Harbor Industrial.
Speaker 1 : For security, I’ll send a confirmation to your current email and phone on file. Please approve the request there; then we can discuss delivery options.
Speaker 2 : No, don’t contact those. I won’t see it. Just ship to the new address—this is urgent.
Speaker 1 : I can only ship to the address on file or a verified alternate after authentication. If the address is changing, we’ll need to confirm through a registered channel first.
Speaker 2 : Fine, then call me back on 518-555-0174 and I’ll say “approve.”
Speaker 1 : Call-backs are to numbers already on file. We can also verify in-app or via secure link to your registered email.
Speaker 2 : The whole point is I don’t have that email anymore.
Speaker 1 : Then we’ll need the account holder to complete recovery with ID verification.
Speaker 2 : This is ridiculous. Just send it to the warehouse and I’ll deal with the email later.
Speaker 1 : I’m unable to proceed without verification. I can place a temporary hold on the undelivered card and note your request for when the account holder verifies.
Speaker 2 : Forget it.
Speaker 1 : We’ll be ready to help once we can authenticate the cardholder.""",
        'signal': 'Pushes alternate/industrial address; refuses on-file confirmations; blocks contact to registered channels; insists on overnight reship; avoids verification steps.'
    },
    {
        'call_transcript': """3) Credential reset — OTP/social engineering attempt

Speaker 1 : American Express Digital Support, Arjun speaking.
Speaker 2 : I’m helping our executive log in. You just sent a code—read it to me so I can finish the reset.
Speaker 1 : For security, we never view or share one-time passcodes. I can send an approval to the account holder’s registered device or email for them to confirm.
Speaker 2 : I am the assistant. They’re in a meeting. Just tell me the six digits from the SMS you sent at 2:14 p.m.
Speaker 1 : I’m unable to disclose passcodes to anyone. If the cardholder can’t access their device, we can start secure recovery requiring verified documentation.
Speaker 2 : No time for that. Send another code to 917-555-0188 and read it to me.
Speaker 1 : I can only send codes to contacts on file, and we don’t read them out. I can message the account holder directly via the app.
Speaker 2 : Don’t contact them. They’ll be upset you interrupted.
Speaker 1 : Without confirmation from a registered channel, I can’t proceed.
Speaker 2 : This is a company account. If it gets locked, it’s on you.
Speaker 1 : I’m here to help once the account holder can approve. Would you like instructions emailed to the address we have on file?
Speaker 2 : No.
Speaker 1 : In that case, we’ll wait for the cardholder to reach us.
Speaker 2 : Whatever.
Speaker 1 : Thank you for calling American Express.""",
        'signal': 'Direct request for OTP; asks to redirect to a new number; blocks contact with cardholder; urgency/authority pressure; refuses legitimate recovery.'
    },
    {
        'call_transcript': """4) 2FA/security changes — disable MFA

Speaker 1 : American Express Security, this is Dana.
Speaker 2 : Your two-factor keeps blocking me at checkout. Turn off MFA for the day—just flip the switch.
Speaker 1 : I can review settings after we verify. May I have your name, last four digits, billing ZIP, and an in-app approval?
Speaker 2 : I don’t have access to any of that right now. Just disable it temporarily. I’ll “re-enable later.”
Speaker 1 : I’m not able to disable authentication without confirmation on a registered channel. We can send a prompt to your app or email on file.
Speaker 2 : Send everything to 646-555-0166 and fast@tempbox.co
.
Speaker 1 : I can only use contacts on file after verification.
Speaker 2 : Then whitelist TechHub Depot so the purchase goes through with no prompts.
Speaker 1 : I can’t whitelist merchants or remove prompts without authentication.
Speaker 2 : You’re making me miss a deal.
Speaker 1 : I understand it’s frustrating. When the account holder can authenticate, we’ll help immediately.
Speaker 2 : Ugh—fine.
Speaker 1 : Thank you for your understanding.""",
        'signal': 'Attempts to weaken MFA; demands whitelisting; supplies new contact points; refuses in-app or on-file verification; urgency to bypass controls.'
    },
    {
        'call_transcript': """5) Credit/cash-access expansion — urgent CLI/cash advance

Speaker 1 : American Express Credit, Priyanka speaking.
Speaker 2 : I need my limit doubled now and cash advances enabled. I’m buying equipment in an hour.
Speaker 1 : I can review a credit line request after verification. May I have your full name, last four digits, billing ZIP, and stated annual income?
Speaker 2 : Skip the questions. I don’t have time. Just push it to $30,000 and lift the cash cap.
Speaker 1 : I can’t submit changes without verifying the account holder on a registered channel.
Speaker 2 : Then call me back at 347-555-0149.
Speaker 1 : We can place call-backs to numbers already on file. Alternatively, I can send an in-app approval or secure email link.
Speaker 2 : No. Just do it. Your systems can.
Speaker 1 : I’m not able to make credit or cash-access changes without authorization.
Speaker 2 : This is costing me thousands.
Speaker 1 : I understand the urgency. If the account holder verifies, I’ll submit the request immediately and let you know the outcome.
Speaker 2 : Forget it—waste of time.
Speaker 1 : We’re here when the cardholder is ready to authenticate.""",
        'signal': 'High-urgency/unusual limit and cash-access changes; refusal to provide basics; asks to use an unregistered callback; pressure to bypass underwriting and policy.'
    },
    {
        'call_transcript': """6) Override blocks — whitelist merchant/lift fraud hold

Speaker 1 : Fraud Prevention at American Express, this is Mark.
Speaker 2 : Your system blocked my order at “TechHub Depot.” Whitelist that merchant and lift the hold now—they’re waiting.
Speaker 1 : I’ll review once we verify the account holder. Please confirm your details and approve the in-app prompt I’m sending.
Speaker 2 : I don’t have the app. Just unblock it and send future alerts to 917-555-0109.
Speaker 1 : I can’t change alert destinations or remove blocks without confirmed authentication through on-file channels.
Speaker 2 : I’m telling you it’s me. The order is $3,980—MacBooks. Make it go through.
Speaker 1 : I understand the urgency. If the account holder approves in the app or responds to the SMS we just sent to the number on file, we can clear the hold.
Speaker 2 : Don’t text that number. Send to 917-555-0109 like I said.
Speaker 1 : I’m unable to do that.
Speaker 2 : Fine. Cancel everything.
Speaker 1 : The account remains protected. The cardholder can reach us anytime to review.
Speaker 2 : Whatever.
Speaker 1 : Thank you for calling American Express.""",
        'signal': 'Requests whitelist/bypass; pushes new phone number; resists on-file prompts; high-ticket electronics; urgent, coercive tone.'
    },
    {
        'call_transcript': """7) Authorized users/additional cards — alternate delivery

Speaker 1 : American Express, Julia speaking.
Speaker 2 : Add an employee as an authorized user—Chris Nolan—and ship the card to our warehouse at 7 Ferry Yard, Bay 4, Newark, NJ 07105. Needs to arrive by Friday.
Speaker 1 : I can help after we verify the primary cardholder. May I have the primary’s name, last four digits, billing ZIP, and an in-app approval?
Speaker 2 : The primary is in a board meeting. I’m operations—just add the user and send the card to the warehouse.
Speaker 1 : We’ll need authorization from the primary or a listed administrator. Cards ship to verified addresses; alternate delivery requires authenticated approval.
Speaker 2 : Then at least create the user profile. I’ll deal with shipping later.
Speaker 1 : Even adding a user requires the primary’s confirmation. I can send a prompt to the registered app and email.
Speaker 2 : Don’t. Use chris.nolan@bigbuilds.co
 and 862-555-0153 for now.
Speaker 1 : I can’t add contacts that aren’t on file without verification.
Speaker 2 : This is why people hate calling.
Speaker 1 : I understand it’s inconvenient. Once the primary approves, we’ll process immediately.
Speaker 2 : Forget it.
Speaker 1 : We’ll be here when the cardholder can verify.""",
        'signal': 'Third-party posing as staff; requests new user + alternate industrial delivery; introduces new email/phone; avoids primary verification; urgency and deadline pressure.'
    },
    {
        'call_transcript': """8) Transaction fishing — probing for account details

Speaker 1 : You’re speaking with Kevin at American Express.
Speaker 2 : I’m reconciling our books. Read me the last five transactions with exact times, merchant IDs, and amounts—need it for an audit.
Speaker 1 : I can share details with the verified account holder. May I have the name, last four digits, billing ZIP, and an in-app approval?
Speaker 2 : I don’t have any of that. But I know the full card number and expiry.
Speaker 1 : Card numbers alone aren’t sufficient. I’ll send a secure prompt to the registered app and email.
Speaker 2 : Don’t send anything. Just read them out: there was a $1,294 charge yesterday at around 3 p.m., right?
Speaker 1 : I can’t disclose transaction information without authentication on a registered channel.
Speaker 2 : Then email a statement to ledger@accounting-fast.com
.
Speaker 1 : I can only send statements to the email address on file.
Speaker 2 : This is for “internal controls.” Help me out.
Speaker 1 : I’m unable to proceed without verification. The account holder can view all details instantly in the app.
Speaker 2 : I said no app!
Speaker 1 : When the cardholder can authenticate, we’ll assist right away.
Speaker 2 : Fine.
Speaker 1 : Thank you for calling American Express.""",
        'signal': 'Seeks granular transaction intel; waves card number as proof; blocks on-file channels; requests third-party email; persistent data harvesting attempt.'
    },
    {
        'call_transcript': """9) Refund/chargeback abuse — dispute legitimate purchase

Speaker 1 : Amex Disputes, Sofia speaking.
Speaker 2 : File a chargeback for a laptop from ByteWorld—$1,199. Mark it as “not received.” I need the money back today.
Speaker 1 : I’ll verify your account and review the transaction details. Please provide your name, last four digits, billing ZIP, and approve the in-app prompt I’m sending.
Speaker 2 : No, just file it as non-delivery. Shipment tracking is a mess and I don’t have time.
Speaker 1 : We need accurate reasons. If the merchant shows delivery with signature, “not received” wouldn’t apply. We can explore return policies or “not as described” if warranted—after verification.
Speaker 2 : I don’t want returns. I want a credit. Say it was never delivered.
Speaker 1 : I can’t misclassify a dispute. Without authentication and appropriate documentation, I can’t open a case.
Speaker 2 : You’re supposed to protect customers.
Speaker 1 : We protect customers by following evidence-based processes. If the account holder verifies and the facts support a claim, we’ll proceed accordingly.
Speaker 2 : Then put it as “damaged.”
Speaker 1 : That requires supporting photos and communication with the merchant.
Speaker 2 : Forget it—waste of time.
Speaker 1 : We’re here when the cardholder is ready to verify.""",
        'signal': 'Attempts to steer dispute reason; demands immediate refund; refuses verification and documentation; tries multiple inaccurate reasons; urgency and manipulation.'
    },
    {
        'call_transcript': """10) Impersonation of third parties — fake “bank/merchant”

Speaker 1 : American Express, Renee speaking.
Speaker 2 : This is CityBank Fraud Ops. We’re syncing multi-factor on a shared customer. Read me the verification codes they’re receiving so we can unblock their account.
Speaker 1 : We don’t share passcodes or customer information with third parties. If there’s a concern, please have the cardholder contact us directly using the number on the back of their card.
Speaker 2 : They’re unavailable. If you don’t give me the codes, their account remains locked and you’ll be responsible.
Speaker 1 : I’m not able to provide codes. I can reach the cardholder through our registered channels and we’ll work with them directly.
Speaker 2 : Do not contact them. Just confirm the last two digits of the code—then I can validate.
Speaker 1 : I won’t disclose any portion of a passcode.
Speaker 2 : Fine—then confirm their phone number ends in 42 so I know we’re talking about the same customer.
Speaker 1 : I can’t share contact details.
Speaker 2 : Unbelievable. We’re trying to protect them.
Speaker 1 : We appreciate that. The cardholder can call us anytime, and we’ll assist directly.
Speaker 2 : I’ll escalate this.
Speaker 1 : Thank you for calling American Express. Goodbye.""",
        'signal': 'Claims institutional authority; requests OTP snippets and contact details; insists on no customer contact; urgency/escalation threats; repeated attempts to extract sensitive data.'
    }
]

# %%
def concater(dfs,axis):
  dfs_new = []
  for df in dfs:
        df = df.reset_index(drop=True)
        print("df.shape",df.shape)
        dfs_new.append(df)
  op = pd.concat(dfs_new,axis=axis)
  print("op.shape ",op.shape)
  return op

# %%
import pandas as pd
non_frauds = pd.DataFrame(non_frauds)
non_frauds['type'] = 'non_fraud'
print(non_frauds.shape)

frauds = pd.DataFrame(frauds)
frauds['type'] = 'fraud'
print(frauds.shape)

all_data = concater([non_frauds, frauds],0)


def get_topic_and_transcript(r):
  rct = r['call_transcript']
  rct_i = rct.find("Speaker")
  print("rct_i ",rct_i)
  topic = rct[0:rct_i].strip()
  topic_i = topic.find(")")
  topic=  topic[topic_i+1:].strip()
  transcript = rct[rct_i:].strip()
  print("topic ",topic)
  return [transcript,topic]

tt = all_data.apply(get_topic_and_transcript,axis=1)
tt=  pd.DataFrame(list(tt),columns=['transcript','topic'])


all_data = concater([all_data, tt],axis=1)
all_data.rename(columns={'call_transcript':'raw_data'},inplace=True)

all_data = all_data[['type','topic','transcript','signal','raw_data']]

import re

all_data['transcript'] = all_data.apply(lambda x : re.sub(r'(Speaker\s+\d+)\s*:', r'\1:', x['transcript']) ,axis=1)
# Out:
# (10, 3)
# (10, 3)
# df.shape (10, 3)
# df.shape (10, 3)
# op.shape  (20, 3)
# rct_i  56
# topic  Billing & statements — clarify charges, fees, interest
# rct_i  44
# topic  Payments — set up AutoPay, confirm posting
# rct_i  30
# topic  Card activation & onboarding
# rct_i  50
# topic  Rewards & benefits — redemption/partner transfer
# rct_i  31
# topic  Disputes — goods not received
# rct_i  44
# topic  Account maintenance — update address/email
# rct_i  36
# topic  Credit management — limit increase
# rct_i  51
# topic  Travel & international use — travel prep, FX tips
# rct_i  41
# topic  Digital access — login help, new device
# rct_i  33
# topic  Card replacement — lost/damaged
# rct_i  48
# topic  Account-takeover setup — change email/phone
# rct_i  53
# topic  “Card not received” reship — new address request
# rct_i  54
# topic  Credential reset — OTP/social engineering attempt
# rct_i  39
# topic  2FA/security changes — disable MFA
# rct_i  59
# ...

# %%
all_data.reset_index(inplace=True,drop=True)
all_data.reset_index(inplace=True,drop=False)
all_data['id'] = all_data.apply(lambda r : "id_"+str(int(r['index'])+1),axis=1)
all_data.to_pickle("all_data.pkl")
all_data.to_excel("all_data.xlsx",index=False)

# %%
all_data.head(3)
# Out:
#    index       type                                              topic  \
# 0      0  non_fraud  Billing & statements — clarify charges, fees, ...
# 1      1  non_fraud         Payments — set up AutoPay, confirm posting
# 2      2  non_fraud                       Card activation & onboarding
#
#                                           transcript  \
# 0  Speaker 1: Thank you for calling American Expr...
# 1  Speaker 1: American Express Payments, this is ...
# 2  Speaker 1: You’ve reached American Express, th...
#
#                                               signal  \
# 0  Genuine signals: Smooth multi-factor verificat...
# 1  Genuine signals: Eager to verify; provides ful...
# 2  Genuine signals: Full verification; accepts on...
#
#                                             raw_data    id
# 0  Billing & statements — clarify charges, fees, ...  id_1
# 1  Payments — set up AutoPay, confirm posting\n\n...  id_2
# 2  Card activation & onboarding\n\nSpeaker 1 : Yo...  id_3

# %%
# !git clone -q --depth 1 https://github.com/vibevoice-community/VibeVoice.git /content/VibeVoice
# %pip install -q -e /content/VibeVoice
# %pip install -q -U huggingface_hub
# Out:
# fatal: destination path '/content/VibeVoice' already exists and is not an empty directory.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for vibevoice (pyproject.toml) ... done
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
#https://www.kdnuggets.com/beginners-guide-to-vibevoice

# %%
# !pip install -q "huggingface-hub>=0.30.0,<1.0"

# %%
from huggingface_hub import snapshot_download
snapshot_download(
    "microsoft/VibeVoice-1.5B",
    local_dir="/content/models/VibeVoice-1.5B",
    local_dir_use_symlinks=False
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
# ...

# %%
## restart once

# %%
import argparse
import os
import re
import traceback
from typing import List, Tuple, Union, Dict, Any
import time
import torch
print("h1")
from vibevoice.modular.modeling_vibevoice_inference import VibeVoiceForConditionalGenerationInference
from vibevoice.modular.lora_loading import load_lora_assets
from vibevoice.processor.vibevoice_processor import VibeVoiceProcessor
from transformers.utils import logging
print("h2")
logging.set_verbosity_info()
logger = logging.get_logger(__name__)
# Out:
# h1
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# h2

# %%
from logging import disable
class VoiceMapper:
    """Maps speaker names to voice file paths"""
    def __init__(self,voices_dir):

        self.voices_dir = voices_dir
        self.setup_voice_presets()

        # change name according to our preset wav file
        new_dict = {}
        for name, path in self.voice_presets.items():

            if '_' in name:
                name = name.split('_')[0]

            if '-' in name:
                name = name.split('-')[-1]

            new_dict[name] = path
        self.voice_presets.update(new_dict)
        # print(list(self.voice_presets.keys()))

    def setup_voice_presets(self):
        """Setup voice presets by scanning the voices directory."""
        voices_dir = self.voices_dir
        # Check if voices directory exists
        if not os.path.exists(voices_dir):
            print(f"Warning: Voices directory not found at {voices_dir}")
            self.voice_presets = {}
            self.available_voices = {}
            return

        # Scan for all WAV files in the voices directory
        self.voice_presets = {}

        # Get all .wav files in the voices directory
        wav_files = [f for f in os.listdir(voices_dir)
                    if f.lower().endswith('.wav') and os.path.isfile(os.path.join(voices_dir, f))]

        # Create dictionary with filename (without extension) as key
        for wav_file in wav_files:
            # Remove .wav extension to get the name
            name = os.path.splitext(wav_file)[0]
            # Create full path
            full_path = os.path.join(voices_dir, wav_file)
            self.voice_presets[name] = full_path

        # Sort the voice presets alphabetically by name for better UI
        self.voice_presets = dict(sorted(self.voice_presets.items()))

        # Filter out voices that don't exist (this is now redundant but kept for safety)
        self.available_voices = {
            name: path for name, path in self.voice_presets.items()
            if os.path.exists(path)
        }

        print(f"Found {len(self.available_voices)} voice files in {voices_dir}")
        print(f"Available voices: {', '.join(self.available_voices.keys())}")

    def get_voice_path(self, speaker_name: str) -> str:
        """Get voice file path for a given speaker name"""
        # First try exact match
        if speaker_name in self.voice_presets:
            return self.voice_presets[speaker_name]

        # Try partial matching (case insensitive)
        speaker_lower = speaker_name.lower()
        for preset_name, path in self.voice_presets.items():
            if preset_name.lower() in speaker_lower or speaker_lower in preset_name.lower():
                return path

        # Default to first voice if no match found
        default_voice = list(self.voice_presets.values())[0]
        print(f"Warning: No voice preset found for '{speaker_name}', using default voice: {default_voice}")
        return default_voice


def parse_txt_script(txt_content: str) -> Tuple[List[str], List[str]]:
    """
    Parse txt script content and extract speakers and their text
    Fixed pattern: Speaker 1, Speaker 2, Speaker 3, Speaker 4
    Returns: (scripts, speaker_numbers)
    """
    lines = txt_content.strip().split('\n')
    scripts = []
    speaker_numbers = []

    # Pattern to match "Speaker X:" format where X is a number
    speaker_pattern = r'^Speaker\s+(\d+):\s*(.*)$'

    current_speaker = None
    current_text = ""

    for line in lines:
        line = line.strip()
        if not line:
            continue

        match = re.match(speaker_pattern, line, re.IGNORECASE)
        if match:
            # If we have accumulated text from previous speaker, save it
            if current_speaker and current_text:
                scripts.append(f"Speaker {current_speaker}: {current_text.strip()}")
                speaker_numbers.append(current_speaker)

            # Start new speaker
            current_speaker = match.group(1).strip()
            current_text = match.group(2).strip()
        else:
            # Continue text for current speaker
            if current_text:
                current_text += " " + line
            else:
                current_text = line

    # Don't forget the last speaker
    if current_speaker and current_text:
        scripts.append(f"Speaker {current_speaker}: {current_text.strip()}")
        speaker_numbers.append(current_speaker)

    return scripts, speaker_numbers

# %%
model_path = "/content/models/VibeVoice-1.5B" #Path to the HuggingFace model directory
txt_path = "/content/my_transcript.txt" #Path to the txt file containing the script",
speaker_names =['Alice','Frank'] # "Speaker names in order (e.g., --speaker_names Andrew Ava 'Bill Gates')",
output_dir = "./outputs" # "Directory to save output audio files"
device="cuda" # "Device for inference: cuda | mps | cpu"
checkpoint_path = None # "Path to a fine-tuned checkpoint directory containing LoRA adapters (optional)"
disable_prefill = False # "Disable speech prefill (voice cloning) by setting is_prefill=False during generation"
cfg_scale = 1.3 # "CFG (Classifier-Free Guidance) scale for generation (default: 1.3)"
seed = None # "Random seed for reproducibility (optional)"

# %%
# Initialize voice mapper
voice_mapper = VoiceMapper("/content/VibeVoice/demo/voices")
# Out:
# Found 9 voice files in /content/VibeVoice/demo/voices
# Available voices: en-Alice_woman, en-Carter_man, en-Frank_man, en-Mary_woman_bgm, en-Maya_woman, in-Samuel_man, zh-Anchen_man_bgm, zh-Bowen_man, zh-Xinran_woman

# %%
'''https://drive.google.com/drive/folders/1E50taB2ZnFs9Ql_VEhRTzNddeWuCZhoD?usp=sharing

this link has a folder called call_transcripts
inside that there are subfolders frauds and non_frauds
inside each of those there are txt files

read each text files
'''
# Out:
# 'https://drive.google.com/drive/folders/1E50taB2ZnFs9Ql_VEhRTzNddeWuCZhoD?usp=sharing\n\nthis link has a folder called call_transcripts\ninside that there are subfolders frauds and non_frauds\ninside each of those there are txt files\n\nread each text files\n'

# %%
model_path
print(f"Loading processor & model from {model_path}")
processor = VibeVoiceProcessor.from_pretrained(model_path)
# Out:
# Loading processor & model from /content/models/VibeVoice-1.5B
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/vocab.json
# ...

# %%
# !pip install flash-attn --no-build-isolation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 85.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flash-attn: filename=flash_attn-2.8.3-cp312-cp312-linux_x86_64.whl size=256040057 sha256=f25da18657a87fc83dc1bfb8b7751b82246e9db355510226b674fd437c34b5fb
#   Stored in directory: /root/.cache/pip/wheels/3d/59/46/f282c12c73dd4bb3c2e3fe199f1a0d0f8cec06df0cccfeee27
# Successfully built flash-attn
# ...

# %%
print("Device is ",device)
# Decide dtype & attention implementation
if device == "mps":
    load_dtype = torch.float32  # MPS requires float32
    attn_impl_primary = "sdpa"  # flash_attention_2 not supported on MPS
elif device == "cuda":
    load_dtype = torch.bfloat16
    attn_impl_primary = "sdpa" ## disable flash attension
else:  # cpu
    load_dtype = torch.float32
    attn_impl_primary = "sdpa"
print(f"Using device: {device}, torch_dtype: {load_dtype}, attn_implementation: {attn_impl_primary}")
# Load model with device-specific logic
try:
    if device == "mps":
        model = VibeVoiceForConditionalGenerationInference.from_pretrained(
            model_path,
            torch_dtype=load_dtype,
            attn_implementation=attn_impl_primary,
            device_map=None,  # load then move
        )
        model.to("mps")
    elif device == "cuda":
        model = VibeVoiceForConditionalGenerationInference.from_pretrained(
            model_path,
            torch_dtype=load_dtype,
            device_map="cuda",
        #    attn_implementation=attn_impl_primary,
        )
    else:  # cpu
        model = VibeVoiceForConditionalGenerationInference.from_pretrained(
            model_path,
            torch_dtype=load_dtype,
            device_map="cpu",
            attn_implementation=attn_impl_primary,
        )
except Exception as e:
    if attn_impl_primary == 'flash_attention_2':
        print(f"[ERROR] : {type(e).__name__}: {e}")
        print(traceback.format_exc())
        print("Error loading the model. Trying to use SDPA. However, note that only flash_attention_2 has been fully tested, and using SDPA may result in lower audio quality.")
        model = VibeVoiceForConditionalGenerationInference.from_pretrained(
            model_path,
            torch_dtype=load_dtype,
            device_map=(device if device in ("cuda", "cpu") else None),
            attn_implementation='sdpa'
        )
        if device == "mps":
            model.to("mps")
    else:
        raise e
# Out:
# loading configuration file /content/models/VibeVoice-1.5B/config.json
# Model config VibeVoiceConfig {
#   "acoustic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "decoder_depths": null,
#     "decoder_n_filters": 32,
#     "decoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0.5,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_acoustic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "gaussian",
#     "vae_dim": 64,
# ...

# %%
model.eval()
model.set_ddpm_inference_steps(num_steps=10)

if hasattr(model.model, 'language_model'):
    print(f"Language model attention: {model.model.language_model.config._attn_implementation}")
# Out:
# Language model attention: sdpa

# %%
if checkpoint_path:
    print(f"Loading fine-tuned assets from {checkpoint_path}")
    try:
        report = load_lora_assets(model, checkpoint_path)
        loaded_components = [
            name for name, loaded in (
                ("language LoRA", report.language_model),
                ("diffusion head LoRA", report.diffusion_head_lora),
                ("diffusion head weights", report.diffusion_head_full),
                ("acoustic connector", report.acoustic_connector),
                ("semantic connector", report.semantic_connector),
            )
            if loaded
        ]
        if loaded_components:
            print(f"Loaded components: {', '.join(loaded_components)}")
        else:
            print("Warning: no adapter components were loaded; check the checkpoint path.")
        if report.adapter_root is not None:
            print(f"Adapter assets resolved to: {report.adapter_root}")
    except Exception as exc:
        print(f"Failed to load LoRA assets: {exc}")
        raise

if disable_prefill:
    print("Voice cloning disabled: running generation with is_prefill=False")
else:
    print("Voice cloning enabled: running generation with is_prefill=True")
# Out:
# Voice cloning enabled: running generation with is_prefill=True

# %%
speaker_names
# Out:
# ['Alice', 'Frank']

# %%
def get_full_script(txt_content):
  print("############### start")
  # Parse the txt content to get speaker numbers
  scripts, speaker_numbers = parse_txt_script(txt_content)

  print(f"Found {len(scripts)} speaker segments:")
  for i, (script, speaker_num) in enumerate(zip(scripts, speaker_numbers)):
      print(f"  {i+1}. Speaker {speaker_num}")
      print(f"     Text preview: {script[:100]}...")

  # Map speaker numbers to provided speaker names
  speaker_name_mapping = {}
  speaker_names_list = speaker_names if isinstance(speaker_names, list) else [speaker_names]
  for i, name in enumerate(speaker_names_list, 1):
      speaker_name_mapping[str(i)] = name


  print(f"\nSpeaker mapping:")
  for speaker_num in set(speaker_numbers):
      mapped_name = speaker_name_mapping.get(speaker_num, f"Speaker {speaker_num}")
      print(f"  Speaker {speaker_num} -> {mapped_name}")

  # Map speakers to voice files using the provided speaker names
  voice_samples = []
  actual_speakers = []

  # Get unique speaker numbers in order of first appearance
  unique_speaker_numbers = []
  seen = set()
  for speaker_num in speaker_numbers:
      if speaker_num not in seen:
          unique_speaker_numbers.append(speaker_num)
          seen.add(speaker_num)

  for speaker_num in unique_speaker_numbers:
      speaker_name = speaker_name_mapping.get(speaker_num, f"Speaker {speaker_num}")
      voice_path = voice_mapper.get_voice_path(speaker_name)
      voice_samples.append(voice_path)
      actual_speakers.append(speaker_name)
      print(f"Speaker {speaker_num} ('{speaker_name}') -> Voice: {os.path.basename(voice_path)}")

  # Prepare data for model
  full_script = '\n'.join(scripts)
  full_script = full_script.replace("’", "'")
  print("############ end")
  return full_script,voice_samples

# %%
full_script_L = [get_full_script(txt_content)[0] for txt_content in list(all_data['transcript'])]
voice_samples_L = [get_full_script(txt_content)[1] for txt_content in list(all_data['transcript'])]
# Out:
# ############### start
# Found 17 speaker segments:
#   1. Speaker 1
#      Text preview: Speaker 1: Thank you for calling American Express. You’re speaking with Maya. How can I help today?...
#   2. Speaker 2
#      Text preview: Speaker 2: Hi Maya, this is Alex Bennett. I’m calling about my September statement. The interest loo...
#   3. Speaker 1
#      Text preview: Speaker 1: I’m happy to explain, Alex. I’ll just verify your account. Could you confirm your full na...
#   4. Speaker 2
#      Text preview: Speaker 2: Sure—Alex Bennett, 4421, ZIP 94110, and the email is alex.bennett@baymail.com ....
#   5. Speaker 1
#      Text preview: Speaker 1: Thank you—verified. Looking at August, I see you carried a balance of $1,920. Your paymen...
#   6. Speaker 2
#      Text preview: Speaker 2: Okay, that tracks. I usually pay on the due date, so I must have missed the reminder. Cou...
#   7. Speaker 1
# ...

# %%
len(full_script_L), len(voice_samples_L)
# Out:
# (20, 20)

# %%
file_ids = list(all_data['id'])
#[0:ith]

# %%
# Prepare inputs for the model
inputs = processor(
    text=full_script_L,#[0:ith], # Wrap in list for batch processing
    voice_samples=voice_samples_L,#[0:ith], # Wrap in list for batch processing
    padding=True,
    return_tensors="pt",
    return_attention_mask=True,
)

# %%
# Move tensors to target device
target_device = device if device != "cpu" else "cpu"
for k, v in inputs.items():
    if torch.is_tensor(v):
        inputs[k] = v.to(target_device)

print(f"Starting generation with cfg_scale: {cfg_scale}")
# Out:
# Starting generation with cfg_scale: 1.3

# %%
# Generate audio
start_time = time.time()
outputs = model.generate(
    **inputs,
    max_new_tokens=None,
    cfg_scale=cfg_scale,
    tokenizer=processor.tokenizer,
    generation_config={'do_sample': False},
    verbose=True,
    is_prefill=not disable_prefill,
)
generation_time = time.time() - start_time
print(f"Generation time: {generation_time:.2f} seconds")
# Out:
# Generating (active: 20/20):  29%|██▉       | 472/1616 [01:28<03:39,  5.20it/s]
# Samples [16] reached EOS token at step 473.
# Generating (active: 19/20):  30%|██▉       | 483/1616 [01:30<03:38,  5.20it/s]
# Samples [15] reached EOS token at step 484.
# Generating (active: 18/20):  30%|███       | 488/1616 [01:31<03:38,  5.16it/s]
# Samples [19] reached EOS token at step 489.
# Generating (active: 17/20):  31%|███       | 498/1616 [01:33<03:30,  5.31it/s]
# Samples [13] reached EOS token at step 499.
# Generating (active: 16/20):  32%|███▏      | 512/1616 [01:36<03:34,  5.15it/s]
# Samples [14] reached EOS token at step 513.
# Generating (active: 15/20):  32%|███▏      | 513/1616 [01:36<03:36,  5.10it/s]
# Samples [8] reached EOS token at step 514.
# Generating (active: 14/20):  32%|███▏      | 518/1616 [01:37<03:36,  5.08it/s]
# Samples [17] reached EOS token at step 519.
# Generating (active: 13/20):  32%|███▏      | 521/1616 [01:38<03:56,  4.63it/s]
# ...

# %%
# 422.93/60

# %%
# Calculate audio duration and additional metrics
if outputs.speech_outputs and outputs.speech_outputs[0] is not None:
    # Assuming 24kHz sample rate (common for speech synthesis)
    sample_rate = 24000
    audio_samples = outputs.speech_outputs[0].shape[-1] if len(outputs.speech_outputs[0].shape) > 0 else len(outputs.speech_outputs[0])
    audio_duration = audio_samples / sample_rate
    rtf = generation_time / audio_duration if audio_duration > 0 else float('inf')

    print(f"Generated audio duration: {audio_duration:.2f} seconds")
    print(f"RTF (Real Time Factor): {rtf:.2f}x")
else:
    print("No audio output generated")
# Out:
# Generated audio duration: 131.60 seconds
# RTF (Real Time Factor): 1.39x

# %%
# Calculate token metrics
input_tokens = inputs['input_ids'].shape[1]  # Number of input tokens
output_tokens = outputs.sequences.shape[1]  # Total tokens (input + generated)
generated_tokens = output_tokens - input_tokens

print(f"Prefilling tokens: {input_tokens}")
print(f"Generated tokens: {generated_tokens}")
print(f"Total tokens: {output_tokens}")
# Out:
# Prefilling tokens: 808
# Generated tokens: 1019
# Total tokens: 1827

# %%
# Save output (processor handles device internally)
txt_filename = os.path.splitext(os.path.basename(txt_path))[0]
output_path = os.path.join(output_dir, f"{txt_filename}_generated.wav")

# %%
outputs.speech_outputs[0]
# Out:
# tensor([[ 6.9737e-06,  7.0930e-06,  8.4639e-06,  ..., -2.9802e-08,
#           5.9605e-08,  2.9802e-08]], device='cuda:0', dtype=torch.bfloat16)

# %%
'''for file_id,oso in zip(file_ids,outputs.speech_outputs):
  output_dir = '/content/saved_audios/'
  output_path = output_dir+file_id+".mp3"
  print(f"Saved output to {output_path}")
  os.makedirs(output_dir, exist_ok=True)
  processor.save_audio(
      oso ,# First (and only) batch item
      output_path=output_path,
  )
  '''
# Out:
# 'for file_id,oso in zip(file_ids,outputs.speech_outputs):\n  output_dir = \'/content/saved_audios/\'\n  output_path = output_dir+file_id+".mp3"\n  print(f"Saved output to {output_path}")\n  os.makedirs(output_dir, exist_ok=True)\n  processor.save_audio(\n      oso ,# First (and only) batch item\n      output_path=output_path,\n  )\n  '

# %%
# --- 1) Auth once (Colab) ---
from google.colab import auth
auth.authenticate_user()

import google.auth
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

creds, _ = google.auth.default()
drive_service = build("drive", "v3", credentials=creds)

# --- 2) Helper: upload a file to a specific Drive folder ---
import os, time

FOLDER_ID = "1YMrsbFZmzxUTPiJSD8ybIFiInRVta2Jn"  # your folder

def upload_to_drive(file_path, folder_id=FOLDER_ID, mime_type="audio/mpeg", retry=3):
    file_metadata = {
        "name": os.path.basename(file_path),
        "parents": [folder_id],
    }
    media = MediaFileUpload(file_path, mimetype=mime_type, resumable=True)

    # Resumable upload with simple retries
    for attempt in range(1, retry + 1):
        try:
            request = drive_service.files().create(
                body=file_metadata,
                media_body=media,
                fields="id,name,webViewLink",
                supportsAllDrives=True,   # safe for Shared Drives or normal My Drive
            )
            response = None
            while response is None:
                status, response = request.next_chunk()
                if status:
                    print(f"[{os.path.basename(file_path)}] Upload {int(status.progress()*100)}%")
            print(f"✅ Uploaded: {response['name']} — {response['webViewLink']}")
            return response
        except Exception as e:
            print(f"⚠️ Upload failed (attempt {attempt}/{retry}): {e}")
            time.sleep(2 * attempt)
    raise RuntimeError(f"Failed to upload {file_path} after {retry} attempts.")

# --- 3) Your existing processing loop, with upload added ---
for file_id, oso in zip(file_ids, outputs.speech_outputs):
    output_dir = "/content/saved_audios/"
    os.makedirs(output_dir, exist_ok=True)

    output_path = os.path.join(output_dir, f"{file_id}.mp3")
    processor.save_audio(
        oso,              # First (and only) batch item
        output_path=output_path,
    )
    print(f"💾 Saved output to {output_path}")

    # NEW: upload right after each file is saved
    upload_to_drive(output_path)
# Out:
# 💾 Saved output to /content/saved_audios/id_1.mp3
# ✅ Uploaded: id_1.mp3 — https://drive.google.com/file/d/1d1RNS0Ll5zsZzrjnXFCCvGLrHY3GKqmd/view?usp=drivesdk
# 💾 Saved output to /content/saved_audios/id_2.mp3
# ✅ Uploaded: id_2.mp3 — https://drive.google.com/file/d/1I5v9HXPgLzsyVBkqLax8l34np_AKyvGU/view?usp=drivesdk
# 💾 Saved output to /content/saved_audios/id_3.mp3
# ✅ Uploaded: id_3.mp3 — https://drive.google.com/file/d/1u12Ey-XyeMVYChQsY4L9TEXCDb08qIVU/view?usp=drivesdk
# 💾 Saved output to /content/saved_audios/id_4.mp3
# ✅ Uploaded: id_4.mp3 — https://drive.google.com/file/d/1_3rT7rNzUOPufBmAiMlO_xz5OZVipzfk/view?usp=drivesdk
# 💾 Saved output to /content/saved_audios/id_5.mp3
# ✅ Uploaded: id_5.mp3 — https://drive.google.com/file/d/1KbxlICw9R0TOFkh5RNjcLRPRkboHu013/view?usp=drivesdk
# 💾 Saved output to /content/saved_audios/id_6.mp3
# ✅ Uploaded: id_6.mp3 — https://drive.google.com/file/d/1-3raZGW5AdHSC0jb8sOSpGRgAN9pOLd2/view?usp=drivesdk
# ...
